# %% [markdown]
# # . Create a scraper for flipkart that will scrape data for search results (atleast up to page 2 if available). For example: search for “mobile” keyword on flipkart and scrape the following parameters from the search results.
#   *  Title
#   *  Ratings
#   *  Price
#   *  URL of that item

# %% [markdown]
# # Beautifu soup

# %%
import pandas as pd
import numpy as np

# %%
# libraries for web scraping
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup

# %%
url = urlopen("https://www.flipkart.com/search?q=mobiles+under+20000+camera+phone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=mobiles+under+20000+camera+phone%7CMobiles&requestId=b20bb147-207f-44e7-b713-bf491ac5ab57&as-searchtext=mobiles%20")

# %% [markdown]
# # URL 1_ST PAGE

# %%
webdata = url.read()                     #reading the data
print(webdata)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
soup1 = soup(webdata)

# %%
url = urlopen('https://www.flipkart.com/search?q=mobiles+under+20000+camera+phone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=mobiles+under+20000+camera+phone%7CMobiles&requestId=b20bb147-207f-44e7-b713-bf491ac5ab57&as-searchtext=mobiles+&page=2')

# %% [markdown]
# # URL SECOND PAGE

# %%
webdata_2 = url.read()
print(webdata_2)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
soup2 = soup(webdata_2)

# %% [markdown]
# # 36 pages domain link

# %%
domain = 'https://www.flipkart.com'
for i in range(1,36):
    print(domain+str(i))
# Out:
# https://www.flipkart.com1
# https://www.flipkart.com2
# https://www.flipkart.com3
# https://www.flipkart.com4
# https://www.flipkart.com5
# https://www.flipkart.com6
# https://www.flipkart.com7
# https://www.flipkart.com8
# https://www.flipkart.com9
# https://www.flipkart.com10
# https://www.flipkart.com11
# https://www.flipkart.com12
# https://www.flipkart.com13
# https://www.flipkart.com14
# https://www.flipkart.com15
# https://www.flipkart.com16
# https://www.flipkart.com17
# https://www.flipkart.com18
# https://www.flipkart.com19
# https://www.flipkart.com20
# https://www.flipkart.com21
# https://www.flipkart.com22
# https://www.flipkart.com23
# https://www.flipkart.com24
# https://www.flipkart.com25
# https://www.flipkart.com26
# https://www.flipkart.com27
# https://www.flipkart.com28
# https://www.flipkart.com29
# https://www.flipkart.com30
# https://www.flipkart.com31
# https://www.flipkart.com32
# https://www.flipkart.com33
# https://www.flipkart.com34
# ...

# %% [markdown]
# # COMBINING TWO PAGES

# %%
final = str(soup1) + str(soup2)

# %%
soupdata = soup(final)

# %%
type(soupdata)            #type
# Out:
# bs4.BeautifulSoup

# %%
soupdata = soup(final,'html.parser')

# %%
containers = soupdata.findAll('div',{'class':'_2kHMtA'})

# %%
print(type(containers),len(containers))
# Out:
# <class 'bs4.element.ResultSet'> 48

# %%
containers[0]                              #container[0]
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&amp;lid=LSTMOBGENJWBPFYJSFT1ZY7B0&amp;marketplace=FLIPKART&amp;q=mobiles+under+20000+camera+phone&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&amp;fm=organic&amp;iid=af36a8d7-432c-4ac5-b441-c8bc63efb24a.MOBGENJWBPFYJSFT.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=itbyqyhtio0000001667404139229&amp;qH=361303bcbce3da42" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/l4n2oi80/mobile/x/o/a/-original-imagfhu75eupxyft.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input clas
# ...

# %%
import re          #regular expression

# %% [markdown]
# # MOBILES IN TWO PAGES

# %%
for container in containers:
    product = container.findAll('div',{'class':'_4rR01T'})
    print(product[0].text.split('-'))
# Out:
# ['SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)']
# ['SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)']
# ['SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)']
# ['realme 9i (Prism Blue, 128 GB)']
# ['realme 9i (Prism Blue, 128 GB)']
# ['realme 9i (Prism Blue, 64 GB)']
# ['realme 9i (Prism Black, 64 GB)']
# ['SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)']
# ['realme 9i (Prism Black, 128 GB)']
# ['realme 9i (Prism Black, 128 GB)']
# ['SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)']
# ['SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)']
# ['Infinix HOT 12 Play (Champagne Gold, 64 GB)']
# ['SAMSUNG Galaxy F22 (Denim Blue, 64 GB)']
# ['realme C35 (Glowing Black, 64 GB)']
# ['MOTOROLA e40 (Pink Clay, 64 GB)']
# ['MOTOROLA e40 (Carbon Gray, 64 GB)']
# ['vivo T1 44W (Starry Sky, 128 GB)']
# ['vivo T1 44W (Ice Dawn, 128 GB)']
# ['SAMSUNG Galaxy F22 (Denim Black, 128 GB)']
# ['SAMSUNG Galaxy F22 (Denim Black, 64 GB)']
# ['vivo T1 5G (Rainbow Fantasy, 128 GB)']
# ['vivo T1 5G (Starlight Black, 128 GB)']
# ...

# %%
soupdata.find('nav',{'class':'yFHi8N'}).a
# Out:
# <a class="ge-49M _2Kfbh8" href="/search?q=mobiles+under+20000+camera+phone&amp;sid=tyy%2C4io&amp;as=on&amp;as-show=on&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&amp;as-pos=1&amp;as-type=RECENT&amp;suggestionId=mobiles+under+20000+camera+phone%7CMobiles&amp;requestId=b20bb147-207f-44e7-b713-bf491ac5ab57&amp;as-searchtext=mobiles+&amp;page=1">1</a>

# %%
page = soupdata.findAll('a',{'class':'ge-49M'})
domain = 'https://www.flipkart.com'
domain + page[1].get('href')
#page[0].get('href')
# Out:
# 'https://www.flipkart.com/search?q=mobiles+under+20000+camera+phone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=mobiles+under+20000+camera+phone%7CMobiles&requestId=b20bb147-207f-44e7-b713-bf491ac5ab57&as-searchtext=mobiles+&page=2'

# %% [markdown]
# # PAGES LINKS

# %%
page = soupdata.findAll('a',{'class':'ge-49M'})
domain = 'https://www.flipkart.com/search?q=mobiles+under+20000+camera+phone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=mobiles+under+20000+camera+phone%7CMobiles&requestId=b20bb147-207f-44e7-b713-bf491ac5ab57&as-searchtext=mobiles%20'
#domain + page[1].get('href')

for i in range(1,36):
    print(domain+str(i))
# Out:
# https://www.flipkart.com/search?q=mobiles+under+20000+camera+phone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=mobiles+under+20000+camera+phone%7CMobiles&requestId=b20bb147-207f-44e7-b713-bf491ac5ab57&as-searchtext=mobiles%201
# https://www.flipkart.com/search?q=mobiles+under+20000+camera+phone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=mobiles+under+20000+camera+phone%7CMobiles&requestId=b20bb147-207f-44e7-b713-bf491ac5ab57&as-searchtext=mobiles%202
# ...

# %%
f = open('Mobiles_data.csv','wb')
f.write('ProductName,Stars,Ratings,Reviews,Price\n'.encode())
for container in containers:
    #Finding Product Name 
    product = container.find('div',{'class':'_4rR01T'})
    ProductName = product.text.split(',')[0]
    
    #Finding Stars
    star = container.find('div',{'class','_3LWZlK'})
    try:
        Stars = star.text
    except:
        Stars = 0
        
    #Finding Rating & Reviews
    Rating = container.find('span',{'class':'_2_R_DZ'})
    try:
        ratRev = re.findall('\d+,?\d*',Rating.text)
        Ratings = ratRev[0].replace(',','')
        Reviews = ratRev[1].replace(',','')
    except:
        Ratings = 0
        Reviews = 0
    #print(Ratings,Reviews) 
    
    #PRICE
    Price = container.find('div',{'class','_30jeq3 _1_WHN1'}).text.replace(',','')
    #print(Price.text)
    
    #Information
    info = container.findAll('li',{'class':'rgWa7D'})
    #ROM = info[0].text
    #Display = info[1].text
    #Camera = info[2].text
    #Processor = info[3].text
    
    #Image
    Image = container.img
    ImageURL = Image.get('src')
    
    print(ProductName,Stars,Ratings,Reviews,Price)
    f.write(f"{ProductName},{Stars},{Ratings},{Reviews},{Price}\n".encode())
    print('\n')
f.close()
# Out:
# SAMSUNG Galaxy F13 (Waterfall Blue 4.4 79688 4076 ₹11999
#
#
# SAMSUNG Galaxy F13 (Nightsky Green 4.4 79688 4076 ₹11999
#
#
# SAMSUNG Galaxy F13 (Sunrise Copper 4.4 79688 4076 ₹11999
#
#
# realme 9i (Prism Blue 4.5 102 219 ₹15129
#
#
# realme 9i (Prism Blue 4.5 23844 1429 ₹16139
#
#
# realme 9i (Prism Blue 4.5 102 219 ₹13619
#
#
# realme 9i (Prism Black 4.5 102 219 ₹13619
#
#
# SAMSUNG Galaxy F23 5G (Aqua Blue 4.3 109 133 ₹18499
#
#
# realme 9i (Prism Black 4.5 102 219 ₹15129
#
#
# realme 9i (Prism Black 4.5 23844 1429 ₹16139
#
#
# SAMSUNG Galaxy F23 5G (Forest Green 4.3 109 133 ₹18499
#
#
# SAMSUNG Galaxy F23 5G (Copper Blush 4.3 109 133 ₹18499
#
#
# Infinix HOT 12 Play (Champagne Gold 4.3 93259 6887 ₹8999
#
#
# SAMSUNG Galaxy F22 (Denim Blue 4.3 95806 9323 ₹11999
#
#
# realme C35 (Glowing Black 4.4 141 894 ₹11999
#
#
# MOTOROLA e40 (Pink Clay 4.1 41082 4234 ₹9999
#
#
# MOTOROLA e40 (Carbon Gray 4.1 41082 4234 ₹9999
#
#
# vivo T1 44W (Starry Sky 4.4 59765 4420 ₹14499
#
#
# ...

# %% [markdown]
# # READING CSV FILE

# %%
df = pd.read_csv("Mobiles_data.csv")

# %%
df.head()
# Out:
#                           ProductName  Stars  Ratings  Reviews   Price
# 0  SAMSUNG Galaxy F13 (Waterfall Blue    4.4    79688     4076  ₹11999
# 1  SAMSUNG Galaxy F13 (Nightsky Green    4.4    79688     4076  ₹11999
# 2  SAMSUNG Galaxy F13 (Sunrise Copper    4.4    79688     4076  ₹11999
# 3               realme 9i (Prism Blue    4.5      102      219  ₹15129
# 4               realme 9i (Prism Blue    4.5    23844     1429  ₹16139

# %%
df.shape
# Out:
# (48, 5)
